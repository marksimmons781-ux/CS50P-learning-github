# %% [markdown]
# <a href="https://colab.research.google.com/github/marksimmons781-ux/CS50P-learning-github/blob/main/stories_df.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Adding a sample story
df_stories.loc[len(df_stories)] = {
 'story_id':1,
 'title': 'The Iron Crown',
 'genre': 'High Fantasy',
 'outline': 'A fallen king seeks to reclaim his throne.',
 'themes': 'Redemption, Power, Loyalty'
}

# Adding a sample character linked to story 1
df_characters.loc[len(df_characters)] = {
    'char_id': 101,
    'story_id': 1,
    'name': 'Alaric Thorne',
    'age': 45,
    'role': 'Protagonist',
    'profile': 'Scarred, tall, wears a tattered cloak.',
    'backstory': 'Former general of the King\'s Guard, exiled 10 years ago.'
}

#Save  to CSV
 df_stories.to_csv('my_stories.csv', index=False)
 df_characters.to_csv('character_profiles.csv', index=False)

 # This command triggers a browser download in Colab
 files.download('my_stories.csv')
 files.download('character_profiles.csv')
 )

# %%
import pandas as pd
from google.colab import files

#--- 1.Story outilnes DataFrame ---
stories_cols = ['story_id', 'title', 'genre', 'outline', 'theme']
df_stories = pd.DataFrame(columns=stories_cols)

# --- 2. The Character Profiles DataFrame ---
# We use seperate columns for profiles andn backstories as requested
chars_cols = ['char_id', 'story_id', 'name', 'age', 'role', 'profile', '']
df_characters = pd.DataFrame(columns=chars_cols)

print("DataFrames initialized")
