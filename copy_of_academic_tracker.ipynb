# %% [markdown]
# <a href="https://colab.research.google.com/github/marksimmons781-ux/CS50P-learning-github/blob/main/copy_of_academic_tracker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Creating your Academic & Certification DataFrame
courses_data = {
    'Course_Name': [
        'Internal Auditing - ISMS',
        'Pandas (Python)',
        'NIST Cybersecurity Framework',
        'ISO 27001 (Operations/Evaluation)',
        'CompTIA A+',
        'uTest Academy'
    ],
    'Status': [
        'Completed',
        'Completed',
        'Completed',
        'In Progress',
        'Completed',
        'In Progress'
    ],
    'Score_Achievement': [
        '92%',
        '100%',
        '80%',
        'Clause 9 reached',
        'CPD Certified',
        'Initial Cycle Passed'
    ],
    'Focus_Area': [
        'Compliance/Audit',
        'Data Engineering',
        'Framework Implementation',
        'Performance Evaluation',
        'IT Operations',
        'QA Testing'
    ]
}

df_courses = pd.DataFrame(courses_data)

# You can now filter to see what you need to focus on today
print("--- Current High-Priority Tasks ---")
print(df_courses[df_courses['Status'] == 'In Progress'])
