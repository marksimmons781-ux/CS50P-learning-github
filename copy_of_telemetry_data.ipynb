# %% [markdown]
# <a href="https://colab.research.google.com/github/marksimmons781-ux/CS50P-learning-github/blob/main/copy_of_telemetry_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Initializing your 29-node (now growing) academic ledger
data = {
    'Node_ID': [30, 31, 32, 33],
    'Course_Name': ['ISO 27001 Management System', 'uTest Academy', 'SQL Fundamentals', 'Java Fundamentals'],
    'Category': ['Compliance', 'VAPT/QA', 'Database', 'Programming'],
    'Status': ['33% Complete (Module 3 Started)', 'Initial Cycle Passed', 'Queued', 'Queued'],
    'Last_Commit': ['Clause 10 Cleared', 'Active Sandbox', 'N/A', 'N/A'],
    'Yield_Potential': ['High (GRC/Audit)', 'High (QA/VAPT)', 'Medium (Data)', 'Medium (System)']
}

df = pd.DataFrame(data)

# Adding your "System Health" metric
df['Brain_Load'] = [0.5, 0.4, 0.0, 0.0]  # Representing current intensity

print(df)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# After mounting, you can access your Google Drive files. For example, if you have a CSV file named `my_data.csv` in the root of your Drive, you can load it into a pandas DataFrame like this:

# %%
import os
import pandas as pd

# Define the path to your Google Drive
drive_path = '/content/drive/MyDrive/'

print(f"Files available in {drive_path}:")
# List all files and directories in MyDrive
for item in os.listdir(drive_path):
    print(item)

print("\nError: 'my_data.csv' was not found in your Google Drive.")
print("Please select the correct file path from the list above if you intended to load a CSV, and replace '/content/drive/MyDrive/my_data.csv' with the chosen path.")
print("If you wish to load a Google Sheet (.gsheet), you typically need to export it as a CSV first, or use a specific library to access Google Sheets directly.")

# The original attempt to read 'my_data.csv' is commented out as it caused an error.
# try:
#     df_from_drive = pd.read_csv('/content/drive/MyDrive/my_data.csv')
#     print('DataFrame loaded successfully from Google Drive:')
#     display(df_from_drive.head())
# except FileNotFoundError:
#     print("Error: 'my_data.csv' not found. Please ensure the file exists and the path is correct.")
# except Exception as e:
#     print(f"An error occurred: {e}")
