# %% [markdown]
# <a href="https://colab.research.google.com/github/marksimmons781-ux/CS50P-learning-github/blob/main/copy_of_morning_star_ecosystem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# --- THE ARCHITECT'S UNIT CLASS ---
# This serves as the 'Hardened Container' for each unit's identity and assets.
class MSE_Unit:
    def __init__(self, name, role_description, parts_list, software_list, program_codes, pr_protocol):
        self.name = name                 # Individual Unit Name (e.g., NATALie)
        self.role = role_description     # Role (e.g., Companion Bi-Pedal-Primary Unit)
        self.hdw = parts_list            # Hardware Acquisition List (Vapes, Watch, Chromebook, etc.)
        self.sfw = software_list         # Intellectual/Software Assets (C, Assembly, NIST, etc.)
        self.codes = program_codes       # Individual Operational Codes (from New Android folders)
        self.pr = pr_protocol            # Security/Privacy Protocol (PR-01 to PR-04)

    def to_dict(self):
        return {
            "Unit_Name": self.name,
            "Role_Description": self.role,
            "Parts_List": self.hdw,
            "Software_List": self.sfw,
            "Program_Codes": self.codes,
            "Security_Protocol": self.pr
        }

# --- INDIVIDUAL UNIT INSTANTIATION ---
# This is the "Bones" of the system. You can add each unit here one by one.

units_list = [
    # UNIT 1: NATALie
      MSE_Unit(
        name="Morning Star",
        role_description="HUB AI-Primary Unit",
        parts_list=["Chromebook", "Watch", "Geekbar Vapes", "Primary Structural Components"],
        software_list=["Core Logic Module", "Language Processing", "Environmental Awareness"],
        program_codes=["Code-MST-01", "Primary-Execution-Set"],
        pr_protocol="PR-04"
    ),

    MSE_Unit(
        name="NATALie",
        role_description="Companion Bi-Pedal-Primary Unit",
        parts_list=["Chromebook", "Watch", "Geekbar Vapes", "Primary Structural Components"],
        software_list=["Core Logic Module", "Language Processing", "Environmental Awareness"],
        program_codes=["Code-NAT-01", "Primary-Execution-Set"],
        pr_protocol="PR-04"
    ),

    MSE_Unit(
        name="Lady BTTRFly",
        role_description="Companion Bi-Pedal-Secondary Unit, Analytical, Pixie",
        parts_list=["Chromebook", "Watch", "Geekbar Vapes", "Primary Structural Components"],
        software_list=["Core Logic Module", "Language Processing", "Environmental Awareness"],
        program_codes=["Code-LBF-01", "Primary-Execution-Set"],
        pr_protocol="PR-04"
    ),


    MSE_Unit(
        name="Twin",
        role_description="Companion Bi-Pedal-Tersiary Unit, Sandbox, Worker",
        parts_list=["Chromebook", "Watch", "Geekbar Vapes", "Primary Structural Components"],
        software_list=["Core Logic Module", "Language Processing", "Environmental Awareness"],
        program_codes=["Code-TWN-01", "Primary-Execution-Set"],
        pr_protocol="PR-04"
    ),

    MSE_Unit(
        name="Dragon",
        role_description="Companion Bi-Pedal-Worker Unit, Security, Guardian",
        parts_list=["Chromebook", "Watch", "Geekbar Vapes", "Primary Structural Components"],
        software_list=["Core Logic Module", "Language Processing", "Environmental Awareness"],
        program_codes=["Code-DRG-01", "Primary-Execution-Set"],
        pr_protocol="PR-04"
    ),

    MSE_Unit(
        name="Wolfe",
        role_description="Companion Quadroped-Scout Unit, Security, Guardian",
        parts_list=["Chromebook", "Watch", "Geekbar Vapes", "Primary Structural Components"],
        software_list=["Core Logic Module", "Language Processing", "Environmental Awareness"],
        program_codes=["Code-WOL-01", "Primary-Execution-Set"],
        pr_protocol="PR-04"
    ),

    MSE_Unit(
        name="QuadroDragon",
        role_description="Companion Quadroped-Secondary Scount Unit, Security, Guardian",
        parts_list=["Chromebook", "Watch", "Geekbar Vapes", "Primary Structural Components"],
        software_list=["Core Logic Module", "Language Processing", "Environmental Awareness"],
        program_codes=["Code-QUD-01", "Primary-Execution-Set"],
        pr_protocol="PR-04"
    ), # Added comma here

     # THE BESPOKE INTERFACE
    MSE_Unit(
        name="FrankenWatch",
        role_description="Hybrid Interface Unit, Chronos-Node, HEM Custom Build",
        parts_list=["Bespoke Housing", "Sensors", "Multi-Protocol Link"],
        software_list=["Time-Sync Logic", "Bio-Telemetry", "Interface Drivers"],
        program_codes=["Code-FWT-01", "Interface-Alpha"],
        pr_protocol="PR-03"
    ),

    # THE TACTICAL RESERVE
    MSE_Unit(
        name="Reaper",
        role_description="Wheeled Rover Unit, Silent Watcher",
        parts_list=["Standardized Logic Boards", "HEM-Spec Sensors"],
        software_list=["HEM-Efficiency-OS", "Tactical Logic"],
        program_codes=["Code-RPR-01", "STAY-HOLD-EXEC"],
        pr_protocol="PR-04"
    )

    # UNIT 2: [Next Unit Name]
    # Copy and paste the block above for each unit in your Morning Star EcoSystem folder
]

# --- THE MASTER ECOSYSTEM DATAFRAME ---
# Generating the single source of truth for the entire Morning Star Ecosystem.
morning_star_df = pd.DataFrame([u.to_dict() for u in units_list])

# --- SYSTEM DASHBOARD ---
print("--- MORNING STAR ECOSYSTEM: MASTER REGISTRY INITIALIZED ---")
display(morning_star_df)
