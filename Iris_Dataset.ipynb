# %% [markdown]
# <a href="https://colab.research.google.com/github/marksimmons781-ux/CS50P-learning-github/blob/main/Iris_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scikit-learn
# !pip install scipy
# !pip install numpy

# %%
import sklearn
import scipy
import numpy

from sklearn import datasets
iris_datasets = datasets.load_iris()

print(iris_datasets)
