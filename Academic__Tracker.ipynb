# %% [markdown]
# <a href="https://colab.research.google.com/github/marksimmons781-ux/CS50P-learning-github/blob/main/Academic__Tracker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Setting display options to ensure all columns/rows show up in your terminal
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)

# Expanded Data Structure with IDs
academic_data = {
    'Course_Name': [
        'General Data Protection Regulation (GDPR)',
        'ISO 27001 (Performance Evaluation)',
        'uTest Academy',
        'Introduction to C and Assembly Language',
        'Intro to IoT',
        'Intro to C# Programming',
        'C++ Programming Language',
        'C Programming - Introduction',
        'How to Become a Software Engineer',
        'Introduction to Python Libraries: SciOy and BumPy',
        'DevOps Fundamentals',
        'Master the Pandas Library in Python',
        'Starting Python Programming',
        'Vulnerability Assessment and Penetration Testing (VAPT)',
        'Internal Auditing - Information Security Management Systems (ISMS)',
        'CyberSecrity with Mobile Device Management (MDM)',
        'Introduction to GPT-3 with Python Create Advanced AI Applications',
        'Japanese Language: Introduction to Japanese Scripts',
        'Introduction to Data Science',
        'CompTIA Security+ (SYO-601)',
        'NIST CyberSecurity Framework (CSF) Foundation',
        'Introduction to Certified Information Security Manager (CISM)',
        'Fundamentals of Open-Source Intelligence (OSINT)',
        'CompTIA A+ 1000 -Part 2',
        'Computer Networking -Digital Network Security',
        'Python for Beginners',
        'CompTIA A+ 1000 - Part 1',
        'Food Safety and Hygiene'
    ],
    'Student_ID': [
        'ID-28008025','ID-28002025','ID-28002025','ID-28002025','ID-28002025', 'ID-28002025', 'ID-28002025', 'ID-28002025', 'ID-28002025',
        'ID-28002025','ID-28002025','ID-28002025','ID-28002025','ID-28002025','ID-28002025','ID-28002025',
        'ID-28002025','ID-28002025','ID-28002025','ID-28002025','ID-28002025','ID-28002025','ID-28002025',
        'ID-28002025','ID-28002025','ID-28002025','ID-28002025','ID-28002025'
        ],
    'Verification_ID': [
        'V-GDPR','V-CAssem','v-IoT', 'V-ISM', 'V-PAN', 'V-NST', 'V-COMP-A12',
        'V-intro-to-C#', 'V-intro-to-C++', # These were previously misaligned, now aligned to their courses (7 items)
        # Placeholder values added to the 27 courses (27 - 7 = 20 placeholders)
        'PENDING','PENDING','PENDING','PENDING','PENDING','PENDING','PENDING',
        'PENDING','PENDING','PENDING','PENDING','PENDING','PENDING','PENDING',
        'PENDING','PENDING','PENDING','PENDING','PENDING'

    ],
    'Status': [
        'Complete','Clause 9', 'Initial Cycle Passed','Complete','Complete','Complete', 'Complete', 'Complete', 'Complete', 'Complete', 'Complete',
        'Complete','Complete','Complete','Complete','Complete','Complete','Complete',
        'Complete','Complete','Complete','Complete','Complete','Complete','Complete',
        'Complete','Complete','Complete'
    ],
    'Score_Achievement': [
        '88%','N/A', 'N/A','88%','84%','92%', '92%', '92%', '92%','84%','80%','100%','100%','84%','92%','88%','90%','80%','84%','88%','80%','92%','88%','92%','84%','80%','91%','100%'
    ],
    'Focus_Area': [
        'European Data Protection Regulation Guidelines','8086 Processor','SMB and the IoT, RFID', 'Compliance/Audit', 'Data Science', 'Frameworks', 'IT Ops', 'ISMS Audit', 'QA Testing',
        'Fundamentals of C#', 'Fundamentals of C++', # These were previously misaligned, now aligned to their courses
        # Placeholder values added to match the 26 courses
        'General','General','General','General','General','General','General',
        'General','General','General','General','General','General','General',
        'General','General','General'
    ]
}

df_academic = pd.DataFrame(academic_data)

# Show ALL courses (Completed and In Progress)
print("--- OFFICIAL ACADEMIC TRANSCRIPT ---")
print(df_academic)

# Export this to a CSV so you have an official file saved in your Garage Hub
df_academic.to_csv('Simmons_Academic_Transcript_2026.csv', index=False)

# %%
print(df_academic.info())
