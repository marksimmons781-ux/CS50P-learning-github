# %% [markdown]
# <a href="https://colab.research.google.com/github/marksimmons781-ux/CS50P-learning-github/blob/main/Master_Stories.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import pandas as pd

print('Author Name: MarkAnthony Simmons')
#Define structure of the DragonLands Epic Saga
Saga_ID = 'DragonLands_Epic_Saga'
Saga_Story_IDs = ['Chronicles of Maester Elian', 'Dragons Awakened', 'The Coming of Dragons', 'Rise of the Dragon Lords', 'The Destruction of Dragons',];
Saga_Character_IDs = ['Rori', 'Tom-Tom', 'Collin Thornwood','Preistess Lorellia','Garret Holstein','Kakaquon','Iron Men','Demon Prince','Ice Cat God','Wiley Longwood','Lorrent','Hamm','Thomas','Peter','Vickon','Beatrice Weatherbee','Saraha-Anne Weatherbee','Lady Vera Thornwood','Kerin','Lanie','Gracelynne Copperton','Millie Copperton',' Kale','Quinn','Julian','Silas',];
Saga_Character_Profiles = ['Orphaned girl','Guardian','Lord of Great Harbor','High Preistess of Temple of Fire','Outlaw former Knight','Karosean Leader','Soldiers from Iron Kingdom','Fallen God','Northern Protective God','Spear of Night','Outlaw former knight','Outlaw former knight','Outlaw','Outlaw','Outlaw','Outlaw','Owner Weatherbee FOrks Inn','Owner Weatherbee FOrks Inn','Lady of Great Harbor','Handmaid','Handmaid','Widowed mother','Gracelynnes Daughter','Trapper','Farmer','vampire','vampire',];
#Define the structure for my story collection
stories_data = {
    'story_id':['Chronicles of Maester Elian', 'Dragons Awakened', 'The Coming of Dragons', 'Rise of the Dragon Lords', 'The Destruction of Dragons','The Mirror Mask','Deception', 'Developing Attractions', 'Constructive Critisim', 'Autumn Rayne', 'Vampires Alive', 'Unidentified', 'Fog', 'Cry For Help', 'Where Are You Now', 'Keri Come Back', 'The New Kid', '6E', 'World On Fire','The Monster Within','Legend of the Vampire','Looking Glass','Reasons Why','My Babys Eyes','Suggestion Of Peace','This Place','The Work of Art'],
    'genre':['High Fantasy','High Fantasy','High Fantasy','High Fantasy','High Fantasy','Sci-Fi', 'Psychological Thriller', 'Romance', 'Romance', 'Romance', 'Sci-fi Horror', 'Murder Mystery', 'Psycological Horror', 'YA', 'YA', 'YA', 'YA', 'Murder Mystery', 'Social Critique Non-Fiction','Self Empowerment','Historical Paranormal Fiction','Poetry','Poetry','Poetry','Poetry','Poetry','Poetry'], # Now 27 elements
    'plot_outline':['A journey through the ancient history of DragonLands, narrated by Maester Elian.', # New plot outline for 'Chronicles of Maester Elian'
                    'The rediscovery of dragons and their impact on the world.', # New plot outline for 'Dragons Awakened'
                    'The initial arrival and devastating power of dragons on the land.', # New plot outline for 'The Coming of Dragons'
                    'The rise of powerful figures who bond with dragons and establish new empires.', # New plot outline for 'Rise of the Dragon Lords'
                    'The eventual downfall and disappearance of dragons from the world.', # New plot outline for 'The Destruction of Dragons'
                    'The discovery of an artifact in the amazon lead an archeologist to new theories of hunan exixtance and the truth of whether or not we are alone in the universe',
                    'A Woman Detective is investigating a string of murders which appear to be connected with a similar one from her past.',
                    'Seeing her boyfriend in a diner sitting at the spot that she claimed was "theirs" Gwen makes the the mistake of assuming he was cheating and causes a devistating outcome in their relationship.',
                    'Gwen must fight to find and reclaim the love of her life but is it already too late or can she reconstruct the love once was again?',
                    'Betrayed by her caregivers and kidnapped by a rugged pirate, Autumn struggles to find her place and a new home free from the control of others.',
                    'A lone survivor fight to stay alive after a vampire apocalypse.',
                    'A detective investigates a series of mysterious disappearances with no clear link.',
                    'A Birch Forest is engulfed by a supernatural fog, trapping its inhabitants with an unseen menace.',
                    'A young adult discovers a hidden message that leads them on a quest for answers.',
                    'A young soldier returns home to reconsile with his family after several years of absense.',
                    'A young girls desperate attempt to get her best friend to come back home to the life that she belongs in.',
                    'A new student at school and her prosthetic leg start a group of students into investigating her past and the creation of a SADD chapter in the school.',
                    'A man begins his mundane tuesday morning preparation for work then discovers his neighbors been killed in his own apartment',
                    'A non-fiction exploration of societal issues leading to global conflict.',
                    'A journey of self-discovery and overcoming inner demons.',
                    'A tragic tale of damnation and legends',
                    'A reflective poem.',
                    'A Poem exploring the motivations behind human actions.',
                    'Poetic observation from a parent\'s perspective.',
                    'A Poem advocating for harmony and tranquility.',
                    'Poetic descriptions of unique and memorable locations.',
                    'A Poem inspired by the inner beauty of nature and individuals.'] # Now 26 elements
}

#Create the DataFrame
df_Stories = pd.DataFrame(stories_data)

# Normalize story_id in df_Stories to match df_Characters format (replace spaces with underscores)
df_Stories['story_id'] = df_Stories['story_id'].str.replace(' ', '_')

#Display the current library of stories
print("---Story Master List---")
display(df_Stories)

# 1. Define the structure for Characters
# We include 'profile' and 'backstory' as separate columns per your request
chars_data = {
    'char_id': ['Rori_ID','Tom-Tom_ID','Collin_Thornwood_ID'],
    'story_id': ['Chronicles_of_Maester_Elian', 'Chronicles_of_Maester_Elian', 'Chronicles_of_Maester_Elian'], # Assigned to first saga story
    'name': ['Rori','Tom-Tom','Collin Thornwood'],
    'role': ['Protagonist','Support','Support'],
    'profile': ['Orphaned girl','Guardian','Lord of Great Harbor'],
    'backstory': ['', '', '']
}

df_Characters = pd.DataFrame(chars_data)

# 2. A function to make adding characters faster
def add_char(c_id, s_id, name, role, profile, backstory):
    global df_Characters
    new_entry = {
        'char_id': c_id,
        'story_id': s_id,
        'name': name,
        'role': role,
        'profile': profile,
        'backstory': backstory
    }
    df_Characters = pd.concat([df_Characters, pd.DataFrame([new_entry])], ignore_index=True)

# 3. Adding your initial characters
add_char('Rori_01', 'Chronicles_of_Maester_Elian', 'Rori', 'Protagonist', 'Young, resilient', 'Lost father to dragon fire, Mother died during childbirth five years; orphaned at 5 years old') # Assigned to first saga story
add_char('Autumn_01', 'Autumn_Rayne', 'Autumn Rayne', 'Protagonist', 'Determined, captive', 'Betrayed by caregivers.')
add_char('Pirate_01', 'Autumn_Rayne', 'Justin Black', 'Antagonist/Love Interest', 'Rugged, mysterious', 'Kidnapped Autumn.')
add_char('Kara_West_ID', 'Deception', 'Kara West', 'Protagonist', 'Detective', 'Investigating a string of murders which have a striking resemblance to one from her own past')
add_char('Dillon_Carter_ID', 'Deception', 'Dillon Carter', 'Support', 'Detective', 'Transferred in from big city must prove to Kara that he is on her side')
add_char('Edward_Tomlin_ID', "Vampires_Alive", 'Edward Tomlin', 'Protagonist', 'Survivor', 'Excaped from Vampire feeding colonies struggling to remain alive and free')
add_char('Garret_Holstein_ID', 'Chronicles_of_Maester_Elian', 'Garret Holstein', 'Antagonist', 'Rapist/murderer/soldier/outlaw', 'Garret is the leader of the former soldier group turned outlaws in the Midland area') # Assigned to first saga story
add_char('Lorrent_ID','Chronicles_of_Maester_Elian', 'Lorrent', 'Antagonist','Outlaw/murderer/rapist/missionary','Lorrent is the second in command of Garrets team he will later become resentful of his past and seek ammends') # Assigned to first saga story
add_char('Tristane_ID','Chronicles_of_Maester_Elian','Tristane','Protector', 'Former Squire','Squire turned knight and sworn sword to Collin Thornwood') # Assigned to first saga story
add_char('Julian_ID', "Legends_of_the_Vampire", "Julian", "Protagonist", "Penatent", "Roman")
add_char('Silas_ID', "Legends_of_the_Vampire", "Silas", "Antagonist", "Supplicant", "American")


print("--- Character Profiles Updated ---")
display(df_Characters)

# Identify stories with missing genre or plot_outline
missing_info_stories = df_Stories[(df_Stories['genre'] == '') | (df_Stories['plot_outline'] == '')]

# Display the stories with missing information
print("---Stories with Missing Genre or Plot Outline---")
display(missing_info_stories)

# Re-create df_Master_View by merging df_Characters and df_Stories
df_Master_View = pd.merge(df_Characters, df_Stories, on='story_id', how='left')

# Define romance_stories DataFrame
romance_stories = df_Stories[df_Stories['genre'] == 'Romance']

# Add 'is_romance' column to df_Master_View
# This checks if the story_id in df_Master_View is present in the romance_stories DataFrame
df_Master_View['is_romance'] = df_Master_View['story_id'].isin(romance_stories['story_id'])

print("---Unified df_Master_View---")
display(df_Master_View.head())


# Create a dictionary to map story titles to their trigger warnings
trigger_warning_map = {
    # Removed generic 'DragonLands_Epic_Saga' key as individual stories now have specific warnings
    'The Monster Within': ['Abuse', 'Domestic Trauma'], # The original 'The Monster Within' from the trigger_warning_map
    'Fairmont': ['None'], # Assuming 'Fairmont' exists in your stories
    'Fog': ['Gore', 'Psychological Horror'],
    'Autumn_Rayne': ['Emotional Manipulation', 'Betrayal'], # Updated story_id to match normalized format
    'Vampires_Alive': ['Gore', 'Violence', 'Survival Themes'], # Updated story_id to match normalized format
    'Unidentified': ['Violence', 'Death'],
    'Cry_For_Help': ['Mental Health Issues', 'Bullying'], # Updated story_id to match normalized format
    'Where_Are_You_Now': ['Loss', 'Grief'], # Updated story_id to match normalized format
    'Keri_Come_Back': ['Separation Anxiety', 'Reconciliation Challenges'], # Updated story_id to match normalized format
    'The_New_Kid': ['Social Exclusion', 'Mystery'], # Updated story_id to match normalized format
    '6E': ['Murder', 'Conspiracy'],
    'World_On_Fire': ['Societal Collapse', 'Conflict'], # Updated story_id to match normalized format
    # Note: 'The Monster Within' was already in the map with ['Abuse', 'Domestic Trauma']. The new suggestion was ['Inner Conflict', 'Self-Doubt']. I will keep the new one and ensure it's unique.
    'The_Monster_Within': ['Inner Conflict', 'Self-Doubt'], # Updated story_id and warning based on suggestion
    'Looking_Glass': ['Existential Themes'], # Updated story_id to match normalized format
    'Reasons_Why': ['Human Flaws', 'Consequences'], # Updated story_id to match normalized format
    'My_Babys_Eyes': ['Parental Anxiety', 'Responsibility'], # Updated story_id to match normalized format
    'Suggestion_Of_Peace': ['Conflict Resolution'], # Updated story_id to match normalized format
    'This_Place': ['Sense of Place', 'Belonging'], # Updated story_id to match normalized format
    'The_Work_of_Art': ['Artistic Struggle'], # Updated story_id to match normalized format
    'Deception': ['Psychological Manipulation', 'Betrayal', 'Murder'], # Added missing entry for 'Deception'
    # Adding trigger warnings for the new Saga stories
    'Chronicles_of_Maester_Elian': ['Historical Violence', 'Political Intrigue'],
    'Dragons_Awakened': ['Fantasy Violence', 'Creature Threat'],
    'The_Coming_of_Dragons': ['War', 'Destruction'],
    'Rise_of_the_Dragon_Lords': ['Power_Struggle', 'Oppression'], # Changed to use underscore
    'The_Destruction_of_Dragons': ['Loss', 'Tragedy']
}

# Add the 'Trigger_Warnings' column to df_Master_View by mapping titles
# For titles not in the map, assign ['None'] as a default
df_Master_View['Trigger_Warnings'] = df_Master_View['story_id'].map(trigger_warning_map).apply(lambda x: x if isinstance(x, list) else ['None'])

# %%
print("---Stories with Missing Plot Outlines---")
missing_plot_outline_stories = missing_info_stories[missing_info_stories['plot_outline'] == '']
display(missing_plot_outline_stories[['story_id', 'genre', 'plot_outline']])

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=genre_distribution.index, y=genre_distribution.values)
plt.title('Distribution of Genres')
plt.xlabel('Genre')
plt.ylabel('Number of Stories')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 6))
sns.barplot(x=role_distribution.index, y=role_distribution.values)
plt.title('Distribution of Character Roles')
plt.xlabel('Character Role')
plt.ylabel('Number of Characters')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 6))
sns.barplot(x=warning_distribution.index, y=warning_distribution.values)
plt.title('Distribution of Trigger Warnings')
plt.xlabel('Trigger Warning Type')
plt.ylabel('Number of Occurrences')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import collections

print("---Trigger Warning Distribution---")

# Initialize an empty dictionary to store the counts of each unique trigger warning
trigger_warning_counts = collections.defaultdict(int)

# Iterate through each list of trigger warnings in the 'Trigger_Warnings' column
for warnings_list in df_Master_View['Trigger_Warnings']:
    # For each warning in each list, update its count
    for warning in warnings_list:
        trigger_warning_counts[warning] += 1

# Convert the trigger_warning_counts dictionary into a Pandas Series and sort it
warning_distribution = pd.Series(trigger_warning_counts).sort_values(ascending=False)

# Display the resulting warning_distribution Series
display(warning_distribution)

# %%
print("---Genre Distribution---")
genre_distribution = df_Master_View['genre'].value_counts()
display(genre_distribution)

print("\n---Character Role Distribution---")
role_distribution = df_Master_View['role'].value_counts()
display(role_distribution)

# %%
print("---First 5 rows of df_Master_View---")
display(df_Master_View.head())

print("\n---df_Master_View Info---")
df_Master_View.info()

print("\n---Shape of df_Master_View---")
print(df_Master_View.shape)

# %%
print("---Characters from 'Chronicles of Maester Elian'---")
chronicles_characters = df_Master_View[df_Master_View['story_id'] == 'Chronicles_of_Maester_Elian']
display(chronicles_characters[['name', 'role', 'profile']])

# %%
print("---High Fantasy Stories---")
high_fantasy_stories = df_Master_View[df_Master_View['genre'] == 'High Fantasy']
display(high_fantasy_stories)

# %%
print("---Updated Story Master List---")
display(df_Stories)

# %%
print("---Updated Story Master List---")
display(df_Stories)

# %%
print("---Stories with Missing Genre or Plot Outline---")
display(missing_info_stories)

# %% [markdown]
# The table above shows the stories that have either a blank genre or a blank plot outline. These are stories where the information is currently incomplete in your `stories_data` dictionary. To make your dataset more comprehensive, you would need to populate these missing values for the listed `story_id`s.

# %%
print("---Genre Distribution in df_Master_View---")
genre_distribution = df_Master_View['genre'].value_counts()
display(genre_distribution)

# %% [markdown]
# # Task
# Analyze `df_Master_View` to understand its structure and content, calculate the distribution of genres, character roles, and trigger warnings, visualize these distributions using bar charts, and summarize the key insights.

# %% [markdown]
# ## Explore df_Master_View
#
# ### Subtask:
# Display the first few rows, columns, and data types of `df_Master_View` to understand its structure and content.

# %% [markdown]
# **Reasoning**:
# To understand the structure and content of `df_Master_View`, I will display its first few rows, column names with their data types, and its dimensions (number of rows and columns).

# %%
print("---First 5 rows of df_Master_View---")
display(df_Master_View.head())

print("\n---df_Master_View Info---")
df_Master_View.info()

print("\n---Shape of df_Master_View---")
print(df_Master_View.shape)

# %% [markdown]
# ## Analyze Genre and Role Distribution
#
# ### Subtask:
# Calculate and display the distribution of genres and character roles within the `df_Master_View`.

# %% [markdown]
# **Reasoning**:
# To analyze the distribution of genres and character roles, I will use the `value_counts()` method on the 'genre' and 'role' columns of `df_Master_View` and then display the results with appropriate headers.

# %%
print("---Genre Distribution---")
genre_distribution = df_Master_View['genre'].value_counts()
display(genre_distribution)

print("\n---Character Role Distribution---")
role_distribution = df_Master_View['role'].value_counts()
display(role_distribution)

# %% [markdown]
# ## Analyze Trigger Warning Distribution
#
# ### Subtask:
# Examine the frequency of different trigger warnings assigned to stories in `df_Master_View`.

# %% [markdown]
# **Reasoning**:
# To analyze the distribution of trigger warnings, I will iterate through the 'Trigger_Warnings' column, count the occurrences of each unique warning, and then display these counts as a sorted Pandas Series.

# %%
import collections

print("---Trigger Warning Distribution---")

# Initialize an empty dictionary to store the counts of each unique trigger warning
trigger_warning_counts = collections.defaultdict(int)

# Iterate through each list of trigger warnings in the 'Trigger_Warnings' column
for warnings_list in df_Master_View['Trigger_Warnings']:
    # For each warning in each list, update its count
    for warning in warnings_list:
        trigger_warning_counts[warning] += 1

# Convert the trigger_warning_counts dictionary into a Pandas Series and sort it
warning_distribution = pd.Series(trigger_warning_counts).sort_values(ascending=False)

# Display the resulting warning_distribution Series
display(warning_distribution)

# %% [markdown]
# ## Visualize Key Distributions
#
# ### Subtask:
# Generate bar charts to visualize the distribution of genres, character roles, and trigger warnings. Ensure all plots have appropriate titles and legends.

# %% [markdown]
# **Reasoning**:
# I will import the necessary libraries for plotting, `matplotlib.pyplot` and `seaborn`, to prepare for creating the visualizations.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Reasoning**:
# Now that the plotting libraries are imported, I will generate bar charts for the distribution of genres, character roles, and trigger warnings, ensuring each plot has an appropriate title and axis labels as specified in the instructions.

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=genre_distribution.index, y=genre_distribution.values)
plt.title('Distribution of Genres')
plt.xlabel('Genre')
plt.ylabel('Number of Stories')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 6))
sns.barplot(x=role_distribution.index, y=role_distribution.values)
plt.title('Distribution of Character Roles')
plt.xlabel('Character Role')
plt.ylabel('Number of Characters')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 6))
sns.barplot(x=warning_distribution.index, y=warning_distribution.values)
plt.title('Distribution of Trigger Warnings')
plt.xlabel('Trigger Warning Type')
plt.ylabel('Number of Occurrences')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
print("---Summary Statistics for df_Characters (Categorical Columns)---")
display(df_Characters.describe(include='object'))

# %%
print("---First 5 rows of df_Master_View---")
display(df_Master_View.head())

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.barplot(x=role_distribution.index, y=role_distribution.values)
plt.title('Distribution of Character Roles')
plt.xlabel('Character Role')
plt.ylabel('Number of Characters')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.barplot(x=genre_distribution.index, y=genre_distribution.values)
plt.title('Distribution of Genres')
plt.xlabel('Genre')
plt.ylabel('Number of Stories')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
print("---Updated Trigger Warning Distribution---")
display(warning_distribution)

# %%
print("---Trigger Warning Distribution---")
display(warning_distribution)

# %%
print("---Stories with 'None' Trigger Warnings---")
# Filter df_Master_View to show only entries where 'Trigger_Warnings' is ['None']
none_trigger_warnings_stories = df_Master_View[df_Master_View['Trigger_Warnings'].apply(lambda x: x == ['None'])]
display(none_trigger_warnings_stories)

# %% [markdown]
# The table above displays stories that currently have 'None' listed as their trigger warning. This indicates that a specific warning has not yet been assigned to these stories. To make the dataset more comprehensive, you might consider reviewing these stories and assigning more granular trigger warnings where appropriate.

# %% [markdown]
# ## Summary of Key Insights
#
# Based on the analysis of `df_Master_View` and the generated visualizations, here are the key insights:
#
# ### 1. Genre Distribution:
# *   **Dominant Genre:** 'High Fantasy' is the most prevalent genre, accounting for 7 entries.
# *   **Other Genres:** 'Romance' and 'Psychological Thriller' each have 2 entries.
# *   **Missing Information:** There is 1 entry with a blank genre, indicating incomplete data that needs to be addressed.
#
# ### 2. Character Role Distribution:
# *   **Protagonists are Key:** 'Protagonist' is the most common role with 5 occurrences, which is expected as every story typically has at least one main character.
# *   **Support Roles:** 'Support' roles are the next most frequent with 2 occurrences, highlighting the presence of secondary characters.
# *   **Antagonistic Roles:** 'Antagonist' and 'Antagonist/Love Interest' roles combined make up 3 occurrences, indicating conflict in some stories.
# *   **Unique Roles:** 'Suppoort' (likely a typo for 'Support') and 'Protector' each appear once.
#
# ### 3. Trigger Warning Distribution:
# *   **Prevalent Warnings:** 'Visceral Violence' and 'Existential Dread' are the most common trigger warnings, each appearing 7 times. This suggests a tendency towards darker or more intense themes in many of the stories.
# *   **Absence of Warnings:** 'None' appears 5 times, indicating stories without specific warnings or stories where warnings have not yet been assigned.
#
# ### Overall Observations:
# *   The `df_Master_View` successfully consolidates character and story information, including derived attributes like `is_romance` and `Trigger_Warnings`.
# *   There is a clear need to fill in missing genre and plot outline information for several stories to ensure a comprehensive dataset.
# *   The presence of generic 'None' trigger warnings suggests that a more granular classification might be beneficial for stories currently without specific tags.
#
# This analysis provides a foundational understanding of the story collection, highlighting its thematic concentrations and areas for data enrichment.

# %% [markdown]
# ## Summary of Key Insights
#
# Based on the analysis of `df_Master_View` and the generated visualizations, here are the key insights:
#
# ### 1. Genre Distribution:
# *   **Dominant Genre:** 'High Fantasy' is the most prevalent genre, accounting for 7 entries.
# *   **Other Genres:** 'Romance' and 'Psychological Thriller' each have 2 entries.
# *   **Missing Information:** There is 1 entry with a blank genre, indicating incomplete data that needs to be addressed.
#
# ### 2. Character Role Distribution:
# *   **Protagonists are Key:** 'Protagonist' is the most common role with 5 occurrences, which is expected as every story typically has at least one main character.
# *   **Support Roles:** 'Support' roles are the next most frequent with 2 occurrences, highlighting the presence of secondary characters.
# *   **Antagonistic Roles:** 'Antagonist' and 'Antagonist/Love Interest' roles combined make up 3 occurrences, indicating conflict in some stories.
# *   **Unique Roles:** 'Suppoort' (likely a typo for 'Support') and 'Protector' each appear once.
#
# ### 3. Trigger Warning Distribution:
# *   **Prevalent Warnings:** 'Visceral Violence' and 'Existential Dread' are the most common trigger warnings, each appearing 7 times. This suggests a tendency towards darker or more intense themes in many of the stories.
# *   **Absence of Warnings:** 'None' appears 5 times, indicating stories without specific warnings or stories where warnings have not yet been assigned.
#
# ### Overall Observations:
# *   The `df_Master_View` successfully consolidates character and story information, including derived attributes like `is_romance` and `Trigger_Warnings`.
# *   There is a clear need to fill in missing genre and plot outline information for several stories to ensure a comprehensive dataset.
# *   The presence of generic 'None' trigger warnings suggests that a more granular classification might be beneficial for stories currently without specific tags.
#
# This analysis provides a foundational understanding of the story collection, highlighting its thematic concentrations and areas for data enrichment.

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Summarize the key insights gathered from the analysis of `df_Master_View`, including predominant genres, character roles, and common trigger warnings.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# The analysis aimed to summarize the key insights gathered from `df_Master_View`, specifically identifying predominant genres, common character roles, and frequently occurring trigger warnings.
#
# ### Data Analysis Key Findings
# *   The `df_Master_View` comprises 12 entries and 11 columns, with no missing values observed in the displayed subset.
# *   **Genre Distribution**: 'High Fantasy' is the most predominant genre, accounting for 7 out of 12 entries. 'Romance' and 'Psychological Thriller' each appear 2 times, while one entry has an unspecified genre.
# *   **Character Role Distribution**: 'Protagonist' is the most frequent character role, appearing 5 times. 'Support' roles occur 2 times, 'Antagonist' roles 2 times, and 'Antagonist/Love Interest', 'Suppoort' (likely a typo for 'Support'), and 'Protector' each appear once.
# *   **Trigger Warning Distribution**: 'Visceral Violence' and 'Existential Dread' are the most common trigger warnings, each appearing 7 times. 'None' is listed as a trigger warning 5 times, indicating stories without specific warnings.
#
# ### Insights or Next Steps
# *   Address the missing genre information for the 1 unspecified entry to ensure data completeness.
# *   Review and standardize character role entries, specifically correcting the 'Suppoort' typo and considering if 'Antagonist/Love Interest' could be further categorized or merged.
# *   Investigate the 5 'None' trigger warning entries to determine if more specific classifications can be applied or if they genuinely lack applicable warnings.

# %% [markdown]
# # Task
# Verify the changes by displaying the head of the `df_Stories` and `df_Master_View` DataFrames, and the `genre_distribution` Series.

# %% [markdown]
# ## Verify Changes
#
# ### Subtask:
# Display the head of the updated `df_Stories` and `df_Master_View` DataFrames, along with the recalculated `genre_distribution` to visually confirm that 'DragonLands' has been restructured into a saga with its component stories and that characters are correctly linked.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# The implicit question addressed by this step is whether the recent data transformations, specifically the restructuring of 'DragonLands' into a saga with its component stories and the correct linking of characters, were successful and accurately reflected in the `df_Stories`, `df_Master_View` DataFrames, and the `genre_distribution` Series.
#
# ### Data Analysis Key Findings
# This verification step was designed to confirm the following:
# *   The successful restructuring of 'DragonLands' into a saga, ensuring its component stories are accurately represented within the `df_Stories` and `df_Master_View` DataFrames.
# *   The accurate establishment of character linkages across the updated DataFrames.
# *   The correct recalculation of the `genre_distribution` Series, reflecting the latest state of the data after transformations.
#
# ### Insights or Next Steps
# *   Successful completion of this verification step would indicate that the data cleaning and restructuring operations were performed correctly, establishing a reliable foundation for subsequent analysis.
# *   In the event of discrepancies observed during verification, it would be necessary to debug and re-execute the relevant preceding data manipulation steps.
